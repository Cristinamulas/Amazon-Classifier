# %%
import nltk
import spacy
import pyforest ## all the machine learnign libreries!
import re
import string

# %%
## Ideas: split the dates into day/ Month/Year/  and do values/counts()
#len of the reviews and tittles and see the distrubution

# %% [markdown]
# ## Load in the Dataset

# %%
df = pd.read_csv("reviews.csv")

# %%
# df.head(20)

# %%
# remove duplicante
duplicates = df[df.Reviews.duplicated(keep = False)].sort_values(by='Reviews')
df.drop_duplicates(subset=['Reviews'],keep=False,inplace = True)

# %%
# df['Reviews']= df.Reviews.apply(lambda x: re.sub(r"[\n\t\s]+",' ', x.lower()))

# %%
for i in df.columns:
    df[i]= df[i].apply(lambda x: re.sub(r"[\n\t\s]+",' ', x.lower()))
    df[i] = df[i].apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x))
    df[i]= df[i].apply(lambda x:re.sub('[‘’“”…]', '', x))

# %%
# df['Reviews'] = df.Reviews.apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x))

# %%
# df['Reviews']= df.Reviews.apply(lambda x:re.sub('[‘’“”…]', '', x))

# %%
# df['Reviews'] = df.Reviews.apply(lambda x: re.sub( r"[\s]+",' ', x))

# %%
# re.sub(r"[\n\t\s]+",' ', x.lower()))
# # remove \n from Reviews and tittles features
# df.Reviews = df.Reviews.str.strip('\n')
# df.Tittles = df.Tittles.str.strip('\n')

# %%
# how to check for duplicates

# %%
# cheking for null values
df.isnull().sum()
# Out:
# Reviews    0
# Date       0
# Names      0
# Tittles    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2388 entries, 0 to 2387
# Data columns (total 4 columns):
# Reviews    2388 non-null object
# Date       2388 non-null object
# Names      2388 non-null object
# Tittles    2388 non-null object
# dtypes: object(4)
# memory usage: 74.7+ KB

# %%
#removed duplicates reviews
df.drop_duplicates(subset=['Reviews'],keep=False,inplace = True)

# %%
df.head()
# Out:
#                                              Reviews              Date  \
# 3  Too many romance novels in ‘literature ‘ selec...  January 22, 2018
# 4  I have tried to use this app but haven't figur...     July 25, 2019
# 5  .i used to be able to drag books from here to ...    March 30, 2018
# 6  It does not seem to have the ability to order ...     March 7, 2019
# 7  It's very useful and convenient for borrowing ...    March 14, 2013
#
#              Names                                            Tittles
# 3         pianogal  this is only reason i downloaded so sorta usel...
# 4  Dita C. Batteau                                   Difficult to Use
# 5           d mede                   Virtual Library with limitations
# 6  Amazon Customer                                     Annoying steps
# 7  daniel talioaga  The choice of free books via Overdrive is horr...

# %% [markdown]
# ## Removing puntuation and capital letters

# %%
# lower all the letters in DF
df = df.applymap(lambda x:x.lower())

# %%
df_try_1
# Out:
#                                                 Reviews                Date  \
# 0     i spoke too soon. i was able to read one book ...   september 8, 2018
# 1     i have used overdrive on my android devices fo...    december 6, 2019
# 2     \ni have used overdrive on my android devices ...    december 6, 2019
# 3     \ntoo many romance novels in ‘literature ‘ sel...    january 22, 2018
# 4     \ni have tried to use this app but haven't fig...       july 25, 2019
# 5     \n.i used to be able to drag books from here t...      march 30, 2018
# 6     \nit does not seem to have the ability to orde...       march 7, 2019
# 7     \nit's very useful and convenient for borrowin...      march 14, 2013
# 8     \ni find this system too annoying to use on a ...       june 24, 2019
# 9     \ni enjoy reading adult mysteries on my kindle...     january 5, 2020
# 10    \nupdate: i spoke to my local library about th...       june 23, 2019
# 11    \ni bought a kindle fire after learning that m...    february 3, 2013
# 12    i spoke too soon. i was able to read one book ...   september 8, 2018
# 13    i have used overdrive on my android devices fo...    december 6, 2019
# 14    \ni loved overdrive and used it consistently u...     january 5, 2020
# 15    \nseems to work ok - just installed yesterday,...    november 3, 2016
# 16    \ni got this app to borrow ebooks from my loca...    january 18, 2019
# 17    \nalthough i use this quite often, it is not a...   december 13, 2014
# 18    \ni would rather have libby so that the same p...       july 24, 2018
# 19    \nit will save me lots of money on kindle book...      august 2, 2019
# 20    \ni have overdrive on both my kindle fire and ...       july 28, 2015
# 21    \nvery disappointed.  the app said it would be...      march 30, 2018
# 22    \nit's a little more difficult for me to use t...    february 4, 2019
# 23    \nthere was a slight learning curve with overd...        july 1, 2014
# 24    i spoke too soon. i was able to read one book ...   september 8, 2018
# 25    i have used overdrive on my android devices fo...    december 6, 2019
# 26    \ni was unable to highlight text and keep note...   september 3, 2019
# 27    \ni was just told about this app to get librar...       june 26, 2015
# 28    \ni am not real cell phone/tablet understandin...     august 10, 2018
# 29    \nneeds improvement limited sources. i can fin...      march 10, 2017
# ...                                                 ...                 ...
# 2358                               \nit doesn't work.\n      april 25, 2018
# 2359  \nupdate does not work on kindle fire tablets -\n   november 14, 2016
# 2360  \ni have not understood this feature of my kin...    january 23, 2014
# 2361  \nminimal directions.  after many tries didn't...     august 28, 2013
# 2362  \ni played with this for a few minutes and cou...       march 6, 2013
# 2363  \nused this app for 5 years with my fire and h...      march 14, 2017
# 2364  i spoke too soon. i was able to read one book ...   september 8, 2018
# 2365  i have used overdrive on my android devices fo...    december 6, 2019
# 2366  \nthis entire website has been changed, & i mu...   september 1, 2016
# 2367  \ni won't say it doesn't work, because it does...     august 20, 2013
# 2368  \ni found that e-books through my public libra...     august 28, 2013
# 2369  \npages don't turn well. hard to navigate. no ...  september 25, 2013
# 2370  \nhaven't figured out how to use it. i really ...   november 19, 2013
# 2371  \nthis app worked really well when it was side...   december 31, 2012
# 2372  \nsounds easy at first, but to download ebooks...    october 14, 2013
# 2373  \nzi find this to be extremely hard to manipul...        may 31, 2013
# 2374  \ntoo cumbersome. should be something more sim...      march 12, 2013
# 2375                          \ncan't get it to work.\n   september 3, 2016
# 2376  i spoke too soon. i was able to read one book ...   september 8, 2018
# 2377  i have used overdrive on my android devices fo...    december 6, 2019
# 2378  \nsince i did not order it , i can't review it.\n   december 31, 2019
# 2379  \nsays books are downloaded, but they aren't. ...        june 3, 2013
# 2380  \ni thought i was losing my mind when i tried ...   february 28, 2013
# 2381  \nit really need fixing i can download an book...   december 28, 2013
# 2382  \ni cannot get into my library books.  its ver...     august 14, 2013
# 2383  \nit was a lot easier to download games and a ...     january 3, 2014
# 2384  \nvery slow to take off.  the first few chapte...       june 24, 2013
# 2385  \nit worked well at first, but then i was unab...      april 21, 2013
# 2386  \nafter trying for three days and downloading ...    january 29, 2013
# 2387  \nwma files are not supported on kindle fire s...      april 11, 2013
#
#                   Names                                            Tittles
# 0        brenda j welsh  \nlibby by overdrive is a necessary app on ama...
# 1       deborah england        \ngreat idea, need help to get it to work\n
# 2       deborah england                               \nstill struggling\n
# 3              pianogal  \nthis is only reason i downloaded so sorta us...
# 4       dita c. batteau                               \ndifficult to use\n
# 5                d mede               \nvirtual library with limitations\n
# 6       amazon customer                                 \nannoying steps\n
# 7       daniel talioaga  \nthe choice of free books via overdrive is ho...
# 8             pj grasse                         \napp no longer works :(\n
# 9        harold ray cox         \nvery good value, but not user friendly\n
# 10          soonerchick                       does not work on kindle fire
# 11               jpinok  libby by overdrive is a necessary app on amazo...
# 12       brenda j welsh   \nthis does not work with the latest apple ios\n
# 13      deborah england  \noverdrive - good program - how do you use it...
# 14    cynthia j. davies                \ngtood app, but hard to navigate\n
# 15            jim tuite  \nneeds a lot of improvement to be user friend...
# 16              marycat                               \ni prefer kindle!\n
# 17                jd bw                                 \nstill learning\n
# 18                 judy                      \nnice app ,but needs work!\n
# 19      georgia edwards  \nvery disappointed. the app said it would be ...
# 20               dom836  \nallows you to borrow e-books and audio books...
# 21        anita corbeil    \nworks well, but could be more user-friendly\n
# 22         texas native                       does not work on kindle fire
# 23              redrosy  libby by overdrive is a necessary app on amazo...
# 24       brenda j welsh                      \nnot a great e-book reader\n
# 25      deborah england                \nwas it overdrive app or amazon?\n
# 26          pastor russ                                  \ngood question\n
# 27           judy vogel  \nneeds improvement limited sources. i can fin...
# 28              samuels                          \ni have it on my phone\n
# 29       steven hoffman                   \nnot good for kindle hd users\n
# ...                 ...                                                ...
# 2358       countryfolks                                          \nbooks\n
# 2359    amazon customer                        \noverdrive media console\n
# 2360        dixie menke                                          \nawful\n
# 2361    amazon customer  \n... for 5 years with my fire and had a prett...
# 2362                edi                       does not work on kindle fire
# 2363     sarah norcross  libby by overdrive is a necessary app on amazo...
# 2364     brenda j welsh                                      \noverdrive\n
# 2365    deborah england                           \nbasically worthless.\n
# 2366    amazon customer                                   \ndisappointed\n
# 2367         michael p.                                   \nhard to use.\n
# 2368     debra sartwell                                          \nstill\n
# 2369                 jj                                         \nbummer\n
# 2370      jeanie barber                               \ndifficult to use\n
# 2371            ddillon                                           \nhelp\n
# 2372                gaz                                  \ndon't like it\n
# 2373         dergrumble                                       \none star\n
# 2374     james milliken                       does not work on kindle fire
# 2375      m. h. goodwin  libby by overdrive is a necessary app on amazo...
# 2376     brenda j welsh                     \ni did not order this item.\n
# 2377    deborah england                                     \ndownloads?\n
# 2378   leonard j panian                      \nuseless to kindle fire hd\n
# 2379        erin zubeck                        \nit is broken fix it plz\n
# 2380                 dg  \noverdrive media library ebooks from the kind...
# 2381       matthew sage                                       \ncomments\n
# 2382            san mcd                 \nnot one of the best odd books.\n
# 2383    nancy prellwitz           \nstarted getting glitchy after awhile\n
# 2384    kindle customer                                  \nnever worked.\n
# 2385                 na                              \nwma not supported\n
# 2386               a.r.                       does not work on kindle fire
# 2387           say what  libby by overdrive is a necessary app on amazo...
#
# [2388 rows x 4 columns]

# %%
nlp = spacy.load('en')

# %%
myfile = open('reviews.csv').read()

# %%
doc_file = nlp(myfile)

# %% [markdown]
# ## tokenization

# %%
tokenization = [token.text for token in doc_file]

# %%
tokenization
# Out:
# ['Reviews',
#  ',',
#  'Date',
#  ',',
#  'Names',
#  ',',
#  'Tittles',
#  '\n',
#  'I',
#  'spoke',
#  'too',
#  'soon',
#  '.',
#  'I',
#  'was',
#  'able',
#  'to',
#  'read',
#  'one',
#  'book',
#  'on',
#  'my',
#  'Kindle',
#  'through',
#  'this',
#  'app',
#  '.',
#  'Now',
#  'when',
#  'I',
#  'try',
#  'to',
#  'sign',
#  'in',
#  'on',
#  'the',
#  'Kindle',
#  'it',
#  'wo',
#  "n't",
#  'even',
#  'go',
#  'to',
#  'the',
#  'search',
#  'page',
#  '.',
#  'There',
#  'is',
#  'no',
#  'way',
#  'for',
#  'me',
#  'to',
#  'locate',
#  'books',
#  'or',
#  'even',
#  'get',
#  'to',
#  'that',
#  'page',
#  '.',
#  'No',
#  'answer',
#  'in',
#  'their',
#  'help',
#  'section',
#  'and',
#  'no',
#  'one',
#  'to',
#  'talk',
#  'to',
#  'about',
#  'it',
#  '.',
#  'I',
#  'am',
#  'able',
#  'to',
#  'access',
#  'on',
#  'my',
#  'phone',
#  '.',
#  'I',
#  'assume',
#  'it',
#  "'s",
#  'the',
#  'Kindle',
#  '.',
#  'Very',
#  'frustrating',
#  'that',
#  'the',
#  'library',
#  'app',
#  'does',
#  'not',
#  'support',
#  'an',
#  'older',
#  'Kindle',
#  'since',
#  'a',
#  'lot',
#  'of',
#  'people',
#  'using',
#  'the',
#  'library',
#  'may',
#  'not',
#  'be',
#  'able',
#  'to',
#  'afford',
#  'the',
#  'latest',
#  'technology.,"September',
#  '8',
#  ',',
#  '2018",Brenda',
#  'J',
#  'Welsh',
#  ',',
#  '"',
#  '\n',
#  'Libby',
#  'by',
#  'Overdrive',
#  'is',
#  'a',
#  'necessary',
#  'app',
#  'on',
#  'Amazon',
#  'Fire',
#  'Tablets',
#  '\n',
#  '"',
#  '\n',
#  '"',
#  'I',
#  'have',
#  'used',
#  'Overdrive',
#  'on',
#  'my',
#  'Android',
#  'devices',
#  'for',
#  'years',
#  'and',
#  'have',
#  'loved',
#  'it',
#  '.',
#  'Switched',
#  'to',
#  'Libby',
#  'by',
#  'Overdrive',
#  'because',
#  'it',
#  'was',
#  'much',
#  'more',
#  'user',
#  'friendly',
#  '.',
#  'I',
#  'bought',
#  'an',
#  'Amazon',
#  'Fire',
#  '7',
#  'for',
#  'my',
#  'senior',
#  'citizen',
#  'mother',
#  'so',
#  'she',
#  'can',
#  'use',
#  'Libby',
#  'only',
#  'to',
#  'find',
#  'out',
#  'that',
#  'Libby',
#  "'s",
#  'not',
#  'available',
#  'and',
#  'Overdrive',
#  'is',
#  'much',
#  'less',
#  'user',
#  'friendly',
#  'on',
#  'Amazon',
#  "'s",
#  'platform',
#  '.',
#  'I',
#  'installed',
#  'the',
#  'app',
#  ',',
#  'downloaded',
#  'the',
#  'books',
#  'I',
#  'wanted',
#  'a',
#  'few',
#  'days',
#  'ago',
#  'and',
#  'now',
#  'they',
#  'are',
#  'inaccessible',
#  '.',
#  'What',
#  'I',
#  ' ',
#  'earth',
#  'happened',
#  '?',
#  'Amazon',
#  ',',
#  'you',
#  'really',
#  'need',
#  'the',
#  'Libby',
#  'platform',
#  '.',
#  'It',
#  "'s",
#  'too',
#  'popular',
#  'not',
#  'to',
#  'have',
#  '.',
#  'It',
#  'is',
#  'user',
#  'friendly',
#  'for',
#  'special',
#  'needs',
#  'and',
#  'older',
#  'and',
#  'younger',
#  'generation',
#  'of',
#  'people.","December',
#  '6',
#  ',',
#  '2019",Deborah',
#  'England',
#  ',',
#  '"',
#  '\n',
#  'Great',
#  'idea',
#  ',',
#  'need',
#  'help',
#  'to',
#  'get',
#  'it',
#  'to',
#  'work',
#  '\n',
#  '"',
#  '\n',
#  '"',
#  '\n',
#  'I',
#  'have',
#  'used',
#  'Overdrive',
#  'on',
#  'my',
#  'Android',
#  'devices',
#  'for',
#  'years',
#  'and',
#  'have',
#  'loved',
#  'it',
#  '.',
#  'Switched',
#  'to',
#  'Libby',
#  'by',
#  'Overdrive',
#  'because',
#  'it',
#  'was',
#  'much',
#  'more',
#  'user',
#  'friendly',
#  '.',
#  'I',
#  'bought',
#  'an',
#  'Amazon',
#  'Fire',
#  '7',
#  'for',
#  'my',
#  'senior',
#  'citizen',
#  'mother',
#  'so',
#  'she',
#  'can',
#  'use',
#  'Libby',
#  'only',
#  'to',
#  'find',
#  'out',
#  'that',
#  'Libby',
#  "'s",
#  'not',
#  'available',
#  'and',
#  'Overdrive',
#  'is',
#  'much',
#  'less',
#  'user',
#  'friendly',
#  'on',
#  'Amazon',
#  "'s",
#  'platform',
#  '.',
#  'I',
#  'installed',
#  'the',
#  'app',
#  ',',
#  'downloaded',
#  'the',
#  'books',
#  'I',
#  'wanted',
#  'a',
#  'few',
#  'days',
#  'ago',
#  'and',
#  'now',
#  'they',
#  'are',
#  'inaccessible',
#  '.',
#  'What',
#  'I',
#  ' ',
#  'earth',
#  'happened',
#  '?',
#  'Amazon',
#  ',',
#  'you',
#  'really',
#  'need',
#  'the',
#  'Libby',
#  'platform',
#  '.',
#  'It',
#  "'s",
#  'too',
#  'popular',
#  'not',
#  'to',
#  'have',
#  '.',
#  'It',
#  'is',
#  'user',
#  'friendly',
#  'for',
#  'special',
#  'needs',
#  'and',
#  'older',
#  'and',
#  'younger',
#  'generation',
#  'of',
#  'people',
#  '.',
#  '\n',
#  '"',
#  ',',
#  '"',
#  'December',
#  '6',
#  ',',
#  '2019",Deborah',
#  'England',
#  ',',
#  '"',
#  '\n',
#  'Still',
#  'Struggling',
#  '\n',
#  '"',
#  '\n',
#  '"',
#  '\n',
#  'Too',
#  'many',
#  'romance',
#  'novels',
#  'in',
#  '‘',
#  'literature',
#  '‘',
#  'selection',
#  '.',
#  'And',
#  'why',
#  'does',
#  'Overdrive',
#  'stop',
#  'working',
#  'if',
#  'WiFi',
#  'is',
#  'n’t',
#  'available',
#  '?',
#  'Selected',
#  'and',
#  'started',
#  'reading',
#  'several',
#  ' ',
#  'books',
#  'to',
#  'read',
#  'on',
#  'a',
#  'recent',
#  'flight',
#  'but',
#  'the',
#  'print',
#  '(',
#  'books',
#  ')',
#  'disappeared',
#  'on',
#  'airplane',
#  '!',
#  ' ',
#  'And',
#  'sometimes',
#  'stops',
#  'working',
#  'at',
#  'home',
#  'too',
#  '.',
#  'Frustrating',
#  '!',
#  '\n',
#  '"',
#  ',',
#  '"',
#  'January',
#  '22',
#  ',',
#  '2018",pianogal',
#  ',',
#  '"',
#  '\n',
#  'this',
#  'is',
#  'only',
#  'reason',
#  'i',
#  'downloaded',
#  'so',
#  'sorta',
#  'useless',
#  'for',
#  'me',
#  '\n',
#  '"',
#  '\n',
#  '"',
#  '\n',
#  'I',
#  'have',
#  'tried',
#  'to',
#  'use',
#  'this',
#  'app',
#  'but',
#  'have',
#  "n't",
#  'figured',
#  'it',
#  'out',
#  'yet',
#  '.',
#  'Others',
#  'seem',
#  'to',
#  'have',
#  'no',
#  'trouble',
#  '.',
#  'When',
#  'I',
#  'get',
#  'time',
#  ',',
#  'I',
#  'will',
#  'look',
#  'more',
#  'closely',
#  'to',
#  'how',
#  'to',
#  'use',
#  'it',
#  '.',
#  'For',
#  'me',
#  ',',
#  'it',
#  "'s",
#  'not',
#  'a',
#  'piece',
#  'of',
#  'cake',
#  'and',
#  'I',
#  'usually',
#  'do',
#  'not',
#  'have',
#  'trouble',
#  'figuring',
#  'these',
#  'apps',
#  'out',
#  '.',
#  '\n',
#  '"',
#  ',',
#  '"',
#  'July',
#  '25',
#  ',',
#  '2019",Dita',
#  'C.',
#  'Batteau',
#  ',',
#  '"',
#  '\n',
#  'Difficult',
#  'to',
#  'Use',
#  '\n',
#  '"',
#  '\n',
#  '"',
#  '\n',
#  '.i',
#  'used',
#  'to',
#  'be',
#  'able',
#  'to',
#  'drag',
#  'books',
#  'from',
#  'here',
#  'to',
#  'adobe',
#  'digital',
#  'editions',
#  'software',
#  'which',
#  'would',
#  'allow',
#  'them',
#  'to',
#  'then',
#  'showup',
#  'on',
#  'my',
#  'nook',
#  '......',
#  'something',
#  'has',
#  'changed',
#  'somewhere',
#  'because',
#  'i',
#  'do',
#  'nt',
#  'seem',
#  'to',
#  'be',
#  'able',
#  'to',
#  'do',
#  'any',
#  'longer',
#  '.....',
#  ' ',
#  'this',
#  'is',
#  'only',
#  'reason',
#  'i',
#  'downloaded',
#  'so',
#  ' ',
#  'sorta',
#  'useless',
#  'for',
#  'me',
#  '\n',
#  '"',
#  ',',
#  '"',
#  'March',
#  '30',
#  ',',
#  '2018",d',
#  'mede',
#  ',',
#  '"',
#  '\n',
#  'Virtual',
#  'Library',
#  'with',
#  'limitations',
#  '\n',
#  '"',
#  '\n',
#  '"',
#  '\n',
#  'It',
#  'does',
#  'not',
#  'seem',
#  'to',
#  'have',
#  'the',
#  'ability',
#  'to',
#  'order',
#  'a',
#  'series',
#  'without',
#  'knowing',
#  'book',
#  'names',
#  ';',
#  'you',
#  'need',
#  'to',
#  'do',
#  'library',
#  'search',
#  'first',
#  'to',
#  'get',
#  'them',
#  '.',
#  'Also',
#  'difficult',
#  'to',
#  'return',
#  'books',
#  'to',
#  'library',
#  'before',
#  'due',
#  'date',
#  '.',
#  'Had',
#  'to',
#  'go',
#  'to',
#  'library',
#  'website',
#  'to',
#  'return',
#  'them',
#  'and',
#  'even',
#  'then',
#  'Amazon',
#  'site',
#  'still',
#  'had',
#  'it',
#  'available',
#  'as',
#  'not',
#  'returned',
#  '.',
#  '\n',
#  '"',
#  ',',
#  '"',
#  'March',
#  '7',
#  ',',
#  '2019",Amazon',
#  'Customer',
#  ',',
#  '"',
#  '\n',
#  'Annoying',
#  'steps',
#  '\n',
#  '"',
#  '\n',
#  '"',
#  '\n',
#  'It',
#  "'s",
#  'very',
#  'useful',
#  'and',
#  'convenient',
#  'for',
#  'borrowing',
#  'materials',
#  '.',
#  'The',
#  '5',
#  'item',
#  'limitation',
#  'helps',
#  'one',
#  'to',
#  'really',
#  'choose',
#  'what',
#  'you',
#  'read',
#  'or',
#  'listen',
#  'to',
#  'so',
#  'one',
#  'does',
#  "n't",
#  'just',
#  'tend',
#  'to',
#  'hoard',
#  'a',
#  'bunch',
#  'of',
#  'books',
#  'one',
#  'may',
#  'ever',
#  'read',
#  'or',
#  'not',
#  '.',
#  'My',
#  'only',
#  'complaint',
#  'is',
#  'that',
#  'I',
#  'chose',
#  'an',
#  'audible',
#  'book',
#  'only',
#  'to',
#  'learn',
#  'after',
#  'I',
#  "'d",
#  'downloaded',
#  'it',
#  'that',
#  'the',
#  'format',
#  'was',
#  "n't",
#  'compatible',
#  'with',
#  'my',
#  'kindle',
#  '.',
#  'And',
#  'there',
#  "'s",
#  'no',
#  'returning',
#  'it',
#  'until',
#  'the',
#  'due',
#  'date',
#  '.',
#  'I',
#  'just',
#  'wish',
#  'there',
#  'could',
#  'have',
#  'been',
#  'some',
#  'kind',
#  'of',
#  'forwarning',
#  'for',
#  'this',
#  'kind',
#  'of',
#  'situation',
#  '.',
#  'So',
#  'now',
#  'I',
#  'have',
#  'one',
#  'less',
#  'item',
#  'I',
#  'am',
#  'able',
#  'to',
#  'choose',
#  'until',
#  'this',
#  'un',
#  '-',
#  'useable',
#  'item',
#  "'s",
#  'date',
#  'expires',
#  '.',
#  'I',
#  'also',
#  'tried',
#  'downloading',
#  'Overdrive',
#  'on',
#  'my',
#  'laptop',
#  'and',
#  'the',
#  'audio',
#  'turned',
#  'out',
#  'to',
#  'also',
#  'be',
#  'incompatible',
#  'for',
#  'some',
#  'reason',
#  'so',
#  'I',
#  'removed',
#  ' ',
#  'it',
#  'altogether',
#  'from',
#  'my',
#  'laptop',
#  '.',
#  'Overdrive',
#  'works',
#  'just',
#  'fine',
#  'for',
#  'e',
#  '-',
#  'books',
#  'on',
#  'my',
#  'kindle',
#  ',',
#  'which',
#  'by',
#  'the',
#  'way',
#  'is',
#  '2013',
#  'hd',
#  '(',
#  'in',
#  'case',
#  'anyone',
#  'else',
#  'might',
#  'have',
#  'a',
#  'similar',
#  'experience',
#  ')',
#  '.',
#  '\n',
#  '"',
#  ',',
#  '"',
#  'March',
#  '14',
#  ',',
#  '2013",daniel',
#  'talioaga',
#  ',',
#  '"',
#  '\n',
#  'The',
#  'choice',
#  'of',
#  'free',
#  'books',
#  'via',
#  'Overdrive',
#  'is',
#  'horrible',
#  '!',
#  '!',
#  '\n',
#  '"',
#  '\n',
#  '"',
#  '\n',
#  'I',
#  'find',
#  'this',
#  'system',
#  'too',
#  'annoying',
#  'to',
#  'use',
#  'on',
#  'a',
#  'consistent',
#  'basis',
#  '.',
#  'Yes',
#  'I',
#  'did',
#  'download',
#  'a',
#  'book',
#  'on',
#  'my',
#  'kindle',
#  'but',
#  'the',
#  'ones',
#  'I',
#  'really',
#  'wanted',
#  'were',
#  'like',
#  '12',
#  'weeks',
#  'out',
#  'to',
#  'download',
#  '.',
#  ...]
