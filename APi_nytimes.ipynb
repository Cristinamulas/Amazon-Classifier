# %% [markdown]
# ### Web Scraping NY times API

# %%
import requests
import json

# %%
# getting the key from a json file in a diferent directory
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
key = get_keys("/Users/cristinamulas/Desktop/webscraping_project/.secret/nyt_apy.json")
apy_key = key['api_key']

# %%
autor = 'Edgar Allan Poe'

url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?query=godfather&api-key='+apy_key

# 'https://api.nytimes.com/svc/books/v3/reviews.json?author='+url_params+'&api-key='+apy_key
print(url)
# 'https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key='+apy_key
# https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key=86HZQa4frAQk3JTlhfdh0FGCW9O4hxHJ'
# https://api.nytimes.com/svc/books/v3/reviews.json?author=Stephen+King&api-key=yourkey





# url_params = str(autor.replace(' ', '+'))

response = requests.get(url)
# Out:
# https://api.nytimes.com/svc/movies/v2/reviews/search.json?query=godfather&api-key=86HZQa4frAQk3JTlhfdh0FGCW9O4hxHJ

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.json().keys()
# Out:
# dict_keys(['status', 'copyright', 'has_more', 'num_results', 'results'])

# %%
response.json()['num_results']
# Out:
# 10

# %%
print(type(response.text))
response.text
# Out:
# <class 'str'>
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['status', 'copyright', 'has_more', 'num_results', 'results'])

# %%
response.json()['num_results']
# Out:
# 10

# %%
import pandas as pd

df = pd.DataFrame.from_dict(response.json()['results'])

# %%
df['summary_short'][0]
# Out:
# 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.'

# %%
df
# Out:
#                                              abstract  \
# 0   The Academy Awards have made mistakes before, ...
# 1   The president’s speech was jammed with enginee...
# 2   He’s a master of manipulating the news media a...
# 3   The former “Nanny” is back with a new NBC sitc...
# 4   David Bowie’s final album reminded her albums ...
# 5   The actress, who has returned to television wi...
# 6   Modern living forced me to grab a movement or ...
# 7   The New Group’s musical adaptation of Paul Maz...
# 8   Hollywood has long cast her as a bombshell (“S...
# 9   Companhia de Dança Deborah Colker returns to t...
# 10  Comedians have always been tempted to make fun...
# 11  Authors describe what it was like to work with...
# 12  A reimagining of his final album by the drumme...
# 13  Lauren Young is the sixth and final woman to t...
# 14  The 1951 movie, which stars Ava Gardner and Ja...
# 15  On top TV shows, the number of such characters...
# ...

# %% [markdown]
# ### top stories API

# %%
# url ='https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key='+apy_key
list_times = [1,7,30]
type_email =["email", "facebook", "twitter"]
for i , u in zip(list_times, type_email):
    url_1day = 'https://api.nytimes.com/svc/mostpopular/v2/shared/{}/{}.json?api-key='.format(i,u)+apy_key
    print(url_1day)
#     response_2 = requests.get(url_1day)
# Out:
# https://api.nytimes.com/svc/mostpopular/v2/shared/1/email.json?api-key=86HZQa4frAQk3JTlhfdh0FGCW9O4hxHJ
# https://api.nytimes.com/svc/mostpopular/v2/shared/7/facebook.json?api-key=86HZQa4frAQk3JTlhfdh0FGCW9O4hxHJ
# https://api.nytimes.com/svc/mostpopular/v2/shared/30/twitter.json?api-key=86HZQa4frAQk3JTlhfdh0FGCW9O4hxHJ

# %%
response_1 = requests.get(url)
print(response_1)
# Out:
# <Response [200]>

# %%
https://api.nytimes.com/svc/mostpopular/v2/shared/{period}/{share_type}.json
# Out:
# 1 email
# 7 facebook
# 30 atwitter

# %%
response_2.json().keys()
# Out:
# dict_keys(['status', 'copyright', 'num_results', 'results'])

# %%
response_2.json()['num_results']
# Out:
# 1749

# %%
for page in range(1,20): # quiero hacer 10 llamadas
    count = 0
    new = []
    response_tr = requests.get(url)
    time.sleep(6)
    count+=20
    new.append(response_tr.json())
print(new)
# Out:
# [{'status': 'OK', 'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.', 'has_more': False, 'num_results': 10, 'results': [{'display_title': 'The Black Godfather', 'mpaa_rating': '', 'critics_pick': 0, 'byline': 'BEN KENIGSBERG', 'headline': '‘The Black Godfather’ Review: The Music Executive Who Made It All Happen', 'summary_short': 'Reginald Hudlin’s documentary about Clarence Avant includes many golden anecdotes.', 'publication_date': '2019-06-06', 'opening_date': '2019-06-07', 'date_updated': '2019-06-14 16:44:01', 'link': {'type': 'article', 'url': 'http://www.nytimes.com/2019/06/06/movies/the-black-godfather-review.html', 'suggested_link_text': 'Read the New York Times Review of The Black Godfather'}, 'multimedia': {'type': 'mediumThreeByTwo210', 'src': 'https://static01.nyt.com/images/2019/06/05/arts/blackgodfather1/blackgodfather1-mediumThreeByTwo210.jpg', 'width': 210, 'height': 140}}, {'display_title': 'Square Grouper: The Godfathers of Ganja', '
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-154-8a95bc8f2005> in <module>
# ----> 1 new[1]
#
# IndexError: list index out of range

# %%
df_new =pd.DataFrame(new[0]['results'])

# %%
df_new
# Out:
#             byline  critics_pick         date_updated  \
# 0   BEN KENIGSBERG             0  2019-06-14 16:44:01
# 1     RACHEL SALTZ             0  2017-11-02 04:18:13
# 2      A. O. Scott             1  2017-11-02 04:16:23
# 3     Janet Maslin             1  2017-11-02 04:17:42
# 4    VINCENT CANBY             1  2017-11-02 04:17:27
# 5       NORA SAYRE             0  2017-11-02 04:16:03
# 6    Vincent Canby             1  2017-11-02 04:17:26
# 7  BOSLEY CROWTHER             0  2017-11-02 04:17:11
# 8           J.T.M.             0  2017-11-02 04:16:58
# 9   Harry T. Smith             0  2017-11-02 04:16:55
#
#                              display_title  \
# 0                      The Black Godfather
# 1  Square Grouper: The Godfathers of Ganja
# 2                         Tokyo Godfathers
# 3                  The Godfather, Part III
# 4                   The Godfather, Part II
# 5                      The Black Godfather
# 6                            The Godfather
# ...

# %%
response_tr.json()['num_results']
# Out:
# 10

# %%
import pandas as pd

df = pd.DataFrame.from_dict(response_1.json()['results'])

# %%
# url ='https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key='+apy_key
list_times = [1,7,30]
type_email =["email", "facebook", "twitter"]
for i , u in zip(list_times, type_email):
    url_1day = 'https://api.nytimes.com/svc/mostpopular/v2/shared/{}/{}.json?api-key='.format(i,u)+apy_key
    print(url_1day)
# Out:
# https://api.nytimes.com/svc/mostpopular/v2/shared/1/email.json?api-key=86HZQa4frAQk3JTlhfdh0FGCW9O4hxHJ
# https://api.nytimes.com/svc/mostpopular/v2/shared/7/facebook.json?api-key=86HZQa4frAQk3JTlhfdh0FGCW9O4hxHJ
# https://api.nytimes.com/svc/mostpopular/v2/shared/30/twitter.json?api-key=86HZQa4frAQk3JTlhfdh0FGCW9O4hxHJ

# %%
response_try = requests.get(url_1day)

# %%
response_try
# Out:
# <Response [200]>

# %%
df_try = pd.DataFrame(response_try.json()['results'])

# %%
df_try
# Out:
#                                              abstract  \
# 0   The New York Times has obtained video of the m...
# 1   Drafts of the book outline the potential testi...
# 2   A little-known start-up helps law enforcement ...
# 3   More and more, new recruits come from the same...
# 4   The retired N.B.A. star, 41, and his daughter ...
# 5   Alcohol was my stress reducer, my reality figh...
# 6   Isabel dos Santos, the daughter of Angola’s fo...
# 7   Across America, working-class people — includi...
# 8   Faith Hope Consolo had the entire press fooled...
# 9   A child of Indian immigrants, she created digi...
# 10  It’s a shame so few of us are taught the basic...
# 11  The president asked his national security advi...
# 12  Journalists are supposed to ask tough question...
# 13  Mr. Greenwald is accused of being part of a “c...
# 14  The diabolical duo of Donald and Mitch, servin...
# 15  Security camera footage verified by The New Yo...
# ...

# %%
response_try.json()['num_results']
# Out:
# 1749

# %%
def get_call(list_t , list_email):
    for time, emails in zip(list_t,list_email):
        url = 'https://api.nytimes.com/svc/mostpopular/v2/shared/{}/{}.json?api-key='.format(i,u)+apy_key
        response = requests.get(url)
        df = pd.DataFrame(response.json()['results'])
        return df

# %%
response_day.json().keys()
# Out:
# dict_keys(['status', 'copyright', 'num_results', 'results'])

# %%
get_call(list_times, type_email)
# Out:
#                                              abstract  \
# 0   The New York Times has obtained video of the m...
# 1   Drafts of the book outline the potential testi...
# 2   A little-known start-up helps law enforcement ...
# 3   More and more, new recruits come from the same...
# 4   The retired N.B.A. star, 41, and his daughter ...
# 5   Alcohol was my stress reducer, my reality figh...
# 6   Isabel dos Santos, the daughter of Angola’s fo...
# 7   Across America, working-class people — includi...
# 8   Faith Hope Consolo had the entire press fooled...
# 9   A child of Indian immigrants, she created digi...
# 10  It’s a shame so few of us are taught the basic...
# 11  The president asked his national security advi...
# 12  Journalists are supposed to ask tough question...
# 13  Mr. Greenwald is accused of being part of a “c...
# 14  The diabolical duo of Donald and Mitch, servin...
# 15  Security camera footage verified by The New Yo...
# ...

# %%
import time

# %%
# def getting_more_data(list_t, list_email):
#     dfs =[]
#     dfs.append(get_call(list_t,list_email))
#     df = pd.concat(dfs, ignore_index=True)

#     return df

# %%
# ll =getting_more_data(list_times,type_email)

# %%
def all_results(list_t , list_email):
    num = response_day.json()['num_results']
    print('{} total matches found.'.format(num))
    cur = 0
    dfs = []
    while cur < num and cur < 100:
        dfs.append(get_call(list_t, list_email))
        time.sleep(1) #Wait a second
        cur += 10
    df = pd.concat(dfs, ignore_index=True)
    return df

# %%
all_results(list_times,type_email)
# Out:
# 310 total matches found.
#                                               abstract  \
# 0    The New York Times has obtained video of the m...
# 1    Drafts of the book outline the potential testi...
# 2    A little-known start-up helps law enforcement ...
# 3    More and more, new recruits come from the same...
# 4    The retired N.B.A. star, 41, and his daughter ...
# 5    Alcohol was my stress reducer, my reality figh...
# 6    Isabel dos Santos, the daughter of Angola’s fo...
# 7    Across America, working-class people — includi...
# 8    Faith Hope Consolo had the entire press fooled...
# 9    A child of Indian immigrants, she created digi...
# 10   It’s a shame so few of us are taught the basic...
# 11   The president asked his national security advi...
# 12   Journalists are supposed to ask tough question...
# 13   Mr. Greenwald is accused of being part of a “c...
# 14   The diabolical duo of Donald and Mitch, servin...
# 15   Security camera footage verified by The New Yo...
# ...

# %%
term = 'pizza'
location = 'Astoria NY'
url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit' : 50
             }
df = all_results(url_params, api_key)
print(len(df))
df.head()

# %%
df = pd.DataFrame(response_day.json()['results'])

# %%
len(df)
# Out:
# 20

# %%
df = pd.DataFrame.from_dict(response_2.json()['results'])

# %%
df
# Out:
#                                              abstract  \
# 0       Even 20-year-olds forget the simplest things.
# 1   Alcohol was my stress reducer, my reality figh...
# 2   G.O.P. senators will harm Congress if they tur...
# 3   I love staying up late, but I hate struggling ...
# 4   There are now a number of medications that may...
# 5   Are we really supposed to look this good at 50...
# 6   This bundle of mischief bears almost no resemb...
# 7   The retired pilot responds to recent comments ...
# 8   The crisis of English departments is also a cr...
# 9   On a wild stretch of Pacific shoreline, Costa ...
# 10  The idea of eternal damnation is neither bibli...
# 11       Everyone with principles has left the party.
# 12  Pharmacists across the U.S. warn that the push...
# 13  “A Very Stable Genius,” by the Washington Post...
# 14  A Cuban doctor waiting for asylum in the Unite...
# 15  There’s a boom in low cost skin-care products ...
# ...

# %%
discover_api_url = 'https://api.themoviedb.org/3/discover/movie? 
api_key=['my api key']&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&primary_release_year=>%3D2004&with_genres=18'

most_popular_films = [] # empty list
new_results = True # true
page = 1 # empiezo desde uno
while new_results: # mientras true
    discover_api = requests.get(discover_api_url + f"&page={page}").json() # get pag 
    new_results = discover_api.get("results", []) # get the resutls
    most_popular_films.extend(new_results) # pegalo
    page += 1 # y vuleve al siguiente

#printing movie_id and movie_title by popularity desc
for i, film in enumerate(most_popular_films):
    print(i, film['id'], film['title']

# %%
#Discover API url filtered to movies >= 2004 and containing Drama genre_ID: 18
discover_api_url = 'https://api.themoviedb.org/3/discover/movie? 
api_key=['my api key']&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&primary_release_year=>%3D2004&with_genres=18'

discover_api = requests.get(discover_api_url).json()
most_popular_films = discover_api["results"]
for page in range(2, discover_api["total_pages"]+1):
    discover_api = requests.get(discover_api_url + f"&page={page}").json()
    most_popular_films.extend(discover_api["results"])

#printing movie_id and movie_title by popularity desc
for i, film in enumerate(most_popular_films):
    print(i, film['id'], film['title'])
